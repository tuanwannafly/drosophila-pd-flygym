# %% [markdown]
# # Experimental Campaign 01 - Healthy Baseline
#
# Planning/execution record template. Do not execute until the campaign is authorized.

# %% [markdown]
# ## Objective
#
# <Record the computational objective.>

# %% [markdown]
# ## Hypothesis
#
# <Record a computational hypothesis without biological overclaiming.>

# %% [markdown]
# ## Dataset
#
# <Record manifest path, version, source commit, and checksums.>

# %% [markdown]
# ## Protocol
#
# <Record configuration, seed, environment, duration, timestep, and command.>

# %% [markdown]
# ## Observations
#
# <Record measured outputs only after authorized execution.>

# %% [markdown]
# ## Validation
#
# <Record checks, pass semantics, warnings, and provenance.>

# %% [markdown]
# ## Limitations
#
# <Record unsupported endpoints and scientific boundaries.>

# %% [markdown]
# ## Next steps
#
# <Record approved next actions only.>
